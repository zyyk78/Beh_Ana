# %%
dir = '/home/zyyk78/HDD/zyyk78/MPtest/G04' 
log_dir='/home/zyyk78/HDD/zyyk78/llom_log'

# %%
#初始化
import os
import fixing
from ParseEvent import ParseEvent
import pickle
import pandas as pd
import warnings
import re
import traceback
warnings.simplefilter(action='ignore', category=FutureWarning)

try:
    if __IPYTHON__:
        get_ipython().run_line_magic('load_ext', 'autoreload')
        get_ipython().run_line_magic('autoreload', '2')
except NameError:
    pass

def find_evt_files_without_pkl(dir=str):
    evt_files_without_pkl = []
    for root, dirs, files in os.walk(dir):
        for file in files:
            if file.endswith('.evt'):
                pkl_file_name = os.path.splitext(file)[0] + '.pkl'
                if pkl_file_name not in files:
                    evt_file_path = os.path.join(root, file)
                    evt_files_without_pkl.append(evt_file_path)
    
    return evt_files_without_pkl

Paths = find_evt_files_without_pkl(dir)
count=0
Event=None
if(len(Paths)==0):
    print('No evt to be processed!\n')
else:
    print('Find '+str(len(Paths))+' File(s)!')

delta1=25000
delta2=10000
df = pd.DataFrame()
if os.path.exists(os.path.join(dir,"README.xlsx")):
    df = pd.read_excel(os.path.join(dir,"README.xlsx"),sheet_name='Sheet1',header=None) .iloc[2:,:]
    print('Find CSV data!')
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# Find 9 File(s)!

# %% [markdown]
# Process All File Automatically！

# %%
while (count < len(Paths)):
    print('Processing file '+str(count+1)+'/'+str(len(Paths))+': '+Paths[count])
    try:
        Event=ParseEvent(Paths[count])
    except Exception as e:
        print('An error occoure while processing Event!' , e)
        Event = {
            'SlnL':{ 'Time_S':[],'Time_E':[]},
            'SlnR':{ 'Time_S':[],'Time_E':[]},
            'ROmL':{ 'Time_S':[],'Time_E':[]},
            'ROmR':{ 'Time_S':[],'Time_E':[]},
            'ModL':{ 'Time_S':[],'Time_E':[]},
            'ModR':{ 'Time_S':[],'Time_E':[]},
            'LickL':{ 'Time_S':[],'Time_E':[]},
            'LickR':{ 'Time_S':[],'Time_E':[]}
        }
    pattern = r'\d{8}'
    target_date = re.findall(pattern, os.path.basename(Paths[count]).split('_')[0]) [0]
    log_file = os.path.join(log_dir, f"log{target_date}.txt")
    matched_row=pd.DataFrame
    if not df.empty:
        matched_row = df[df[0]==int(target_date)] 
        print('Find matched row in CSV data!')
        print(f'Target Tring mode: {matched_row.iloc[0,2]}')
    try:
        Event=fixing.fixing(Event,26000,39000,log_file,matched_row)
    except Exception as e:
        print(f'Error occurred while fixing the event: {e}')
        traceback.print_exc()
        Event=None
    if (Event != None):
        pkl_path=os.path.splitext(Paths[count])[0] + '.pkl'
        with open(pkl_path,"wb") as pkl_f:
            pickle.dump(Event,pkl_f)
            Event=None
        print('File Saved to: '+pkl_path)
    else:
        print('Event = Null!! Pkl won\'t be saved!')
    count += 1
print('All Finished!\n')
# Out:
# Processing file 1/9: /home/zyyk78/HDD/zyyk78/MPtest/G04/20251225F7W_00.evt
# Removed an abnormal event
# Removed an abnormal event
# Removed an abnormal event
# Removed an abnormal event
# Removed an abnormal event
# Removed an abnormal event
# Removed an abnormal event
# Removed an abnormal event
# Removed an abnormal event
# Removed an abnormal event
# Removed an abnormal event
# Removed an abnormal event
# No missing event, skipping fixing
# File Saved to: /home/zyyk78/HDD/zyyk78/MPtest/G04/20251225F7W_00.pkl
# Processing file 2/9: /home/zyyk78/HDD/zyyk78/MPtest/G04/20251216W7W_00.evt
# Removed an abnormal event
# Removed an abnormal event
# Removed an abnormal event
# Removed an abnormal event
# Removed an abnormal event
# No missing event, skipping fixing
# File Saved to: /home/zyyk78/HDD/zyyk78/MPtest/G04/20251216W7W_00.pkl
# Processing file 3/9: /home/zyyk78/HDD/zyyk78/MPtest/G04/20251215W7W_00.evt
# Removed an abnormal event
# Removed an abnormal event
# Removed an abnormal event
# Removed an abnormal event
# No missing event, skipping fixing
# File Saved to: /home/zyyk78/HDD/zyyk78/MPtest/G04/20251215W7W_00.pkl
# Processing file 4/9: /home/zyyk78/HDD/zyyk78/MPtest/G04/20251209W7_00.evt
# Removed an abnormal event
# Removed an abnormal event
# Removed an abnormal event
# Removed an abnormal event
# Removed an abnormal event
# Removed an abnormal event
# Removed an abnormal event
# Removed an abnormal event
# No missing event, skipping fixing
# File Saved to: /home/zyyk78/HDD/zyyk78/MPtest/G04/20251209W7_00.pkl
# Processing file 5/9: /home/zyyk78/HDD/zyyk78/MPtest/G04/20251217W7W_00.evt
# Removed an abnormal event
# Removed an abnormal event
# No missing event, skipping fixing
# File Saved to: /home/zyyk78/HDD/zyyk78/MPtest/G04/20251217W7W_00.pkl
# Processing file 6/9: /home/zyyk78/HDD/zyyk78/MPtest/G04/20251210W7W_00.evt
# Removed an abnormal event
# Removed an abnormal event
# Removed an abnormal event
# Removed an abnormal event
# Removed an abnormal event
# Removed an abnormal event
# Removed an abnormal event
# No missing event, skipping fixing
# File Saved to: /home/zyyk78/HDD/zyyk78/MPtest/G04/20251210W7W_00.pkl
# Processing file 7/9: /home/zyyk78/HDD/zyyk78/MPtest/G04/20251208W7_00.evt
# Removed an abnormal event
# Removed an abnormal event
# Removed an abnormal event
# No missing event, skipping fixing
# File Saved to: /home/zyyk78/HDD/zyyk78/MPtest/G04/20251208W7_00.pkl
# Processing file 8/9: /home/zyyk78/HDD/zyyk78/MPtest/G04/20251211W7W_00.evt
# Removed an abnormal event
# Removed an abnormal event
# Removed an abnormal event
# Removed an abnormal event
# Removed an abnormal event
# No missing event, skipping fixing
# File Saved to: /home/zyyk78/HDD/zyyk78/MPtest/G04/20251211W7W_00.pkl
# Processing file 9/9: /home/zyyk78/HDD/zyyk78/MPtest/G04/20251218F7W_00.evt
# Removed an abnormal event
# Removed an abnormal event
# Removed an abnormal event
# Removed an abnormal event
# Removed an abnormal event
# Removed an abnormal event
# No missing event, skipping fixing
# File Saved to: /home/zyyk78/HDD/zyyk78/MPtest/G04/20251218F7W_00.pkl
# All Finished!
